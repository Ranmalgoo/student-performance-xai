# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

# %%
X = pd.read_csv("../data/processed/X.csv")
y = pd.read_csv("../data/processed/y.csv")
X.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.023046  1.143856  1.360371  0.792251 -0.042286 -0.449944  0.062194
# 1  0.238380 -1.600009 -1.399970 -0.643249 -0.042286 -0.449944  1.178860
# 2 -1.330954 -1.600009 -1.399970 -0.643249 -0.042286  3.589323  0.062194
# 3 -1.330954  1.143856 -0.479857 -0.643249  1.150779 -0.449944 -1.054472
# 4 -0.546287  0.229234  0.440257 -0.643249 -0.042286 -0.449944  0.062194
#
#           7         8         9  ...        33        34        35        36  \
# 0 -0.236010  0.801479 -0.540699  ...  0.668496 -0.296908  2.597133 -1.257656
# 1 -0.236010 -0.097908 -0.540699  ... -1.495896 -0.296908 -0.385040  0.795130
# 2 -0.236010 -0.997295  0.583385  ...  0.668496 -0.296908  2.597133 -1.257656
# 3 -1.238419 -0.997295 -0.540699  ...  0.668496 -0.296908 -0.385040  0.795130
# 4 -0.236010 -0.997295 -0.540699  ... -1.495896 -0.296908 -0.385040  0.795130
#
#          37        38        39       40        41        42
# 0 -0.919671 -1.017881  0.507899  0.23094 -2.232677 -0.708450
# 1 -0.919671 -1.017881 -1.968894  0.23094  0.447893 -0.708450
# 2  1.087346 -1.017881  0.507899  0.23094  0.447893 -0.708450
# 3  1.087346  0.982433  0.507899  0.23094  0.447893  1.411533
# 4  1.087346 -1.017881  0.507899  0.23094 -2.232677 -0.708450
#
# [5 rows x 43 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

# %%
models = {
    "Logistic": LogisticRegression(max_iter=1000),
    "RandomForest": RandomForestClassifier(),
    "XGBoost": XGBClassifier()
}

# %%
for name, model in models.items():
    model.fit(X_train, y_train.values.ravel())
    preds = model.predict(X_test)

    print("Model:", name)
    print(classification_report(y_test, preds))
# Out:
# Model: Logistic
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.81        39
#            1       0.92      0.89      0.90        80
#
#     accuracy                           0.87       119
#    macro avg       0.85      0.87      0.86       119
# weighted avg       0.88      0.87      0.88       119
#
# Model: RandomForest
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        39
#            1       0.96      0.86      0.91        80
#
#     accuracy                           0.88       119
#    macro avg       0.86      0.89      0.87       119
# weighted avg       0.90      0.88      0.88       119
#
# Model: XGBoost
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82        39
#            1       0.93      0.88      0.90        80
#
#     accuracy                           0.87       119
#    macro avg       0.85      0.87      0.86       119
# weighted avg       0.88      0.87      0.88       119
